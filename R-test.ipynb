# %%
?help

# %%
myString <- "Hello, World!"

print ( myString)
# Out:
# [1] "Hello, World!"

# %%
x <- c(11, 30, 39, 20)
labels <- c("70后", "80后", "90后", "00后")
# Plot the chart.
pie(x,labels)
# Out:
# plot without title
