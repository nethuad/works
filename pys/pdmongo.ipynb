# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient('localhost',27017)
db  = client['items']
pk10 = db['scrapy_items']

# %%
data = pd.DataFrame(list(pk10.find()))

# %%
data.head()
# Out:
#                         _id           author  bio birthdate name  \
# 0  5b617caf9303fc1c90c43623  Albert Einstein  NaN       NaN  NaN
# 1  5b617caf9303fc1c90c43624     J.K. Rowling  NaN       NaN  NaN
# 2  5b617caf9303fc1c90c43625  Albert Einstein  NaN       NaN  NaN
# 3  5b617caf9303fc1c90c43626      Jane Austen  NaN       NaN  NaN
# 4  5b617caf9303fc1c90c43627   Marilyn Monroe  NaN       NaN  NaN
#
#                                              tags  \
# 0        [change, deep-thoughts, thinking, world]
# 1                            [abilities, choices]
# 2  [inspirational, life, live, miracle, miracles]
# 3              [aliteracy, books, classic, humor]
# 4                    [be-yourself, inspirational]
#
#                                                 text
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                           _id               author  \
# 0    5b617caf9303fc1c90c43623      Albert Einstein
# 1    5b617caf9303fc1c90c43624         J.K. Rowling
# 2    5b617caf9303fc1c90c43625      Albert Einstein
# 3    5b617caf9303fc1c90c43626          Jane Austen
# 4    5b617caf9303fc1c90c43627       Marilyn Monroe
# 5    5b617caf9303fc1c90c43628      Albert Einstein
# 6    5b617caf9303fc1c90c43629           André Gide
# 7    5b617caf9303fc1c90c4362a     Thomas A. Edison
# 8    5b617caf9303fc1c90c4362b    Eleanor Roosevelt
# 9    5b617caf9303fc1c90c4362c         Steve Martin
# 10   5b617caf9303fc1c90c4362d       Marilyn Monroe
# 11   5b617caf9303fc1c90c4362e         J.K. Rowling
# 12   5b617caf9303fc1c90c4362f      Albert Einstein
# 13   5b617caf9303fc1c90c43630           Bob Marley
# 14   5b617caf9303fc1c90c43631            Dr. Seuss
# 15   5b617caf9303fc1c90c43632        Douglas Adams
# 16   5b617caf9303fc1c90c43633          Elie Wiesel
# ...
